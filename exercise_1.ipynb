# %% [markdown]
# ## Exercise 1: NumPy array Indexing/Slicing
#
# 1.1) In this exercise, we will use the iris dataset. Load the "iris.csv" using the appropriate method for this file type (use the new functions from the package).

# %%
from src.si.io.csv_file import read_csv
import numpy as np

iris = read_csv("datasets/iris/iris.csv", label=True, features=True)

# Print the shape of the dataset
print("Dataset Shape:", iris.X.shape, "\n")

# Print a summary of the dataset
print("Dataset Summary:\n", iris.summary(), "\n")

# Print unique labels
print("Dataset Labels:\n", np.unique(iris.y), "\n")

# Print the unique labels and their counts
unique_labels, label_counts = np.unique(iris.y, return_counts=True)
print("Label Counts:")
for label, count in zip(unique_labels, label_counts):
    print(f"{label}: {count}")
# Out:
# Dataset Shape: (150, 4)
#
# Dataset Summary:
#          sepal_length  sepal_width  petal_length  petal_width
# mean        5.843333     3.054000      3.758667     1.198667
# median      5.800000     3.000000      4.350000     1.300000
# min         4.300000     2.000000      1.000000     0.100000
# max         7.900000     4.400000      6.900000     2.500000
# var         0.681122     0.186751      3.092425     0.578532
#
# Dataset Labels:
#  ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
#
# Label Counts:
# Iris-setosa: 50
# Iris-versicolor: 50
# Iris-virginica: 50

# %% [markdown]
# 1.2) Select the penultimate independent variable.
# What is the dimension of the resulting array?

# %%
print("Penultimate Independent Variable:", iris.features[-1])
print("Array Shape:", iris.X[:,-2].shape)
# Out:
# Penultimate Independent Variable: petal_width
# Array Shape: (150,)

# %% [markdown]
# 1.3) Select the last 10 samples from the iris dataset. What is the mean of the last 10 samples for each independent variable/feature?

# %%
last_10_rows = iris.X[-10:]
print("Mean of each variable:", np.mean(last_10_rows, axis=0))
# Out:
# Mean of each variable: [6.45 3.03 5.33 2.17]

# %% [markdown]
# 1.4) Select all samples from the dataset with values less than or equal to 6 for all independent variables/features. How many samples do you obtain?

# %%
mask = (iris.X <= 6).all(axis=1) #mask of samples with values less than or equal to 6 for all independent variables/features

print("Number of Samples:", iris.X[mask].shape[0])
# Out:
# Number of Samples: 89

# %% [markdown]
# 1.5) Select all samples with a class/label different from 'Iris-setosa'. How many samples do you obtain?

# %%
mask = (iris.y != 'Iris-setosa') #mask of samples with a class/label different from 'Iris-setosa'

print("Number of Samples:", iris.X[mask].shape[0])
# Out:
# Number of Samples: 100
